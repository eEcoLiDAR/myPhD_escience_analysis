# %% [markdown]
# # 1. Exploration analysis of Dutch Vegetation Database

# %%
import pandas as pd

inputdir="/home/komazsofi/Work/Amsterdam/GitHub/ecolidar_WetLand/Data/"
filename="0009022-170826194755519"

in_vegdb=pd.read_csv(inputdir+filename+".csv",sep='\t')

# drop out lines which do not have coordinates
in_vegdb.drop(in_vegdb[in_vegdb.decimallatitude.isnull()].index, inplace=True)
in_vegdb.drop(in_vegdb[in_vegdb.species.isnull()].index, inplace=True)

# get info about the data
#in_vegdb.head()
in_vegdb.dtypes
#in_vegdb.species.unique()
# Out:
# gbifid                             int64
# datasetkey                        object
# occurrenceid                      object
# kingdom                           object
# phylum                            object
# class                             object
# order                             object
# family                            object
# genus                             object
# species                           object
# infraspecificepithet              object
# taxonrank                         object
# scientificname                    object
# countrycode                       object
# locality                         float64
# publishingorgkey                  object
# decimallatitude                  float64
# decimallongitude                 float64
# coordinateuncertaintyinmeters    float64
# coordinateprecision              float64
# elevation                        float64
# elevationaccuracy                float64
# depth                            float64
# depthaccuracy                    float64
# eventdate                         object
# day                                int64
# month                              int64
# year                               int64
# taxonkey                         float64
# specieskey                       float64
# basisofrecord                     object
# institutioncode                   object
# collectioncode                   float64
# catalognumber                    float64
# recordnumber                     float64
# identifiedby                     float64
# license                           object
# rightsholder                     float64
# recordedby                       float64
# typestatus                       float64
# establishmentmeans               float64
# lastinterpreted                   object
# mediatype                        float64
# issue                             object
# dtype: object

# %% [markdown]
# ## 1.1. Area of interest

# %%
# define rectangular area

print(in_vegdb.decimallongitude.min(),in_vegdb.decimallongitude.max())
print(in_vegdb.decimallatitude.min(),in_vegdb.decimallatitude.max())

long_min=4.5
long_max=4.58
lat_min=52.1
lat_max=52.15

in_vegdb_sel=in_vegdb[(in_vegdb['decimallongitude']>long_min) & (in_vegdb['decimallongitude']<long_max) & 
         (in_vegdb['decimallatitude']>lat_min) & (in_vegdb['decimallatitude']<lat_max)]

in_vegdb_sel.shape
# Out:
# 4.3988 5.22974
# 52.13199 52.59753
# (127, 44)

# %% [markdown]
# ## 1.2. Exploration analysis

# %%
from bokeh.charts import Bar, output_file, show
from bokeh.io import output_notebook
from bokeh.models.widgets import Panel, Tabs
from bokeh.plotting import figure

output_notebook()

p1=Bar(in_vegdb_sel, 'order')
tab1 = Panel(child=p1, title="order")

p2=Bar(in_vegdb_sel, 'family')
tab2 = Panel(child=p2, title="family")

tabs = Tabs(tabs=[ tab1, tab2 ])

show(tabs)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="97e2792e-d63a-4490-b61d-2bf5ab1b479f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="b25e6c7f-2a88-43dc-a50c-05926e7c453c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b25e6c7f-2a88-43dc-a50c-05926e7c453c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b25e6c7f-2a88-43dc-a50c-05926e7c453c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b25e6c7f-2a88-43dc-a50c-05926e7c453c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"06f08fe1-3184-405e-8e36-5912a5ca9a50":{"roots":{"references":[{"attributes":{"data_source":{"id":"02640c67-93c8-456e-9bd0-78a17f1a0102","type":"ColumnDataSource"},"glyph":{"id":"5b056b7c-2ec8-4bea-880b-61a203683689","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3bf18eb3-0f14-47fb-8044-5bec0ab2925a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"541ad734-23cb-49dd-9413-2ad6e829eca9","subtype":"Chart","type":"Plot"}},"id":"60eff09f-6e4b-4117-9fd2-c345a3c147bc","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"dd1bba99-a8a5-4389-943b-38aa252fffeb","type":"ColumnDataSource"},"glyph":{"id":"6fde6ba0-cb9c-47f9-8a33-fc8fba030ee7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8ddff21a-0387-44c4-89d6-dcb30958f6bc","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"14769069-b6bb-439e-bb51-91d449b582b0","type":"ColumnDataSource"},"glyph":{"id":"f90769c8-bebb-49ab-a593-e37f96fce378","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8102bf31-9750-4647-a45a-070092be4a6e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e353ae94-f5af-4336-b87e-f03c62d665e5","type":"ColumnDataSource"},"glyph":{"id":"283696f5-bc74-4f12-bdce-c9f4e40ffe6d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7b612b33-28df-4469-a027-fa4fc24fe8c2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a882f13f-d9fe-4c7b-b4a0-ccbc07d4e477","type":"Rect"},{"attributes":{"callback":null,"factors":["Apiales","Asparagales","Asterales","Brassicales","Caryophyllales","Dipsacales","Equisetales","Fabales","Fagales","Gentianales","Geraniales","Hypnales","Lamiales","Poales","Ranunculales","Rosales"]},"id":"3368d3e8-743f-4648-8c3b-575f6bb45716","type":"FactorRange"},{"attributes":{},"id":"52311e76-22bb-4695-93b2-cd9008ff0434","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["fill_alpha","label","y","color","x","width","line_alpha","line_color","height"],"data":{"chart_index":[{"family":"Fagaceae"}],"color":["#f22c40"],"family":["Fagaceae"],"fill_alpha":[0.8],"height":[1.0],"label":[{"family":"Fagaceae"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Fagaceae"],"y":[0.5]}},"id":"e353ae94-f5af-4336-b87e-f03c62d665e5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["fill_alpha","label","y","color","x","width","line_alpha","line_color","height"],"data":{"chart_index":[{"order":"Asterales"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[12.0],"label":[{"order":"Asterales"}],"line_alpha":[1.0],"line_color":["white"],"order":["Asterales"],"width":[0.8],"x":["Asterales"],"y":[6.0]}},"id":"4f9b7f7f-9d38-4215-baaf-6d2d33cb888d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b2ea336e-9904-4bf1-8428-cddf8012630f","type":"Rect"},{"attributes":{"data_source":{"id":"a915e6cf-1ea0-4bba-9a5a-e49e0dc2adfd","type":"ColumnDataSource"},"glyph":{"id":"054df192-5c59-413b-a0f8-fe2a33e97f39","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6fbbac22-a8bb-447a-abf4-afeb929e1db6","type":"GlyphRenderer"},{"attributes":{"axis_label":"Order","formatter":{"id":"52311e76-22bb-4695-93b2-cd9008ff0434","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"541ad734-23cb-49dd-9413-2ad6e829eca9","subtype":"Chart","type":"Plot"},"ticker":{"id":"e7374928-88f0-4305-bd27-1c659152ef52","type":"CategoricalT ...

# %% [markdown]
# ## 1.3. Geospatial visualization

# %%
import folium
from folium import plugins

base_map = folium.Map(location=[52, 5], zoom_start=5)
marker = folium.plugins.MarkerCluster().add_to(base_map)

for name, row in in_vegdb_sel.iterrows():
    folium.Marker([row["decimallatitude"], row["decimallongitude"]], popup=row["species"]).add_to(marker)

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
