# %% [markdown]
# Import data

# %%
import pandas as pd
import numpy as np

from IPython.display import display, HTML

# %%
filepath="D:\\GitHub\\eEcoLiDAR\\Annotation\\Data\\"

header=pd.read_csv(filepath+'Phragmites_australis_header.csv',sep='\t')
species=pd.read_csv(filepath+'Phragmites_australis_species.csv',sep='\t')

print(header.dtypes)
print("-----------------")
print(species.dtypes)
# Out:
# PlotObservationID                   int64
# PlotID                              int64
# Bedekkingsschaal                   object
# Datum van opname                   object
# Lengte proefvlak (m)              float64
# Breedte proefvlak (m)             float64
# Opp. proefvlak (m²)               float64
# Bedekking totaal (%)              float64
# Bedekking boomlaag (%)            float64
# Bedekking struiklaag (%)          float64
# Bedekking kruidlaag (%)           float64
# Bedekking moslaag (%)             float64
# Hoogte (hoge) boomlaag (m)        float64
# Hoogte lage boomlaag (m)          float64
# Hoogte (hoge) struiklaag (m)      float64
# Hoogte lage struiklaag (m)        float64
# Gem. hoogte (hoge) kruidl (cm)    float64
# Gem. hoogte lage kruidl. (cm)     float64
# Maximale hoogte kruidlaag (cm)    float64
# Associa (1)                        object
# Incompleteness (1)                float64
# Longitude                         float64
# ...

# %%
year=2005

#print(header["Datum van opname"].str[-4:].astype('float64'))

header_upyear=header[(header["Datum van opname"].str[-4:].astype('float64')>year)]

# %%
pd.set_option('display.max_columns', None)
header_upyear.head(n=20)

header_specific=header[(header["PlotObservationID"]==192)]
header_specific
# Out:
#    PlotObservationID  PlotID        Bedekkingsschaal Datum van opname  \
# 0                192     192  Braun/Blanquet (B,D&S)         2-9-1996
#
#    Lengte proefvlak (m)  Breedte proefvlak (m)  Opp. proefvlak (m²)  \
# 0                   2.0                    2.0                  4.0
#
#    Bedekking totaal (%)  Bedekking boomlaag (%)  Bedekking struiklaag (%)  \
# 0                  70.0                     NaN                       NaN
#
#    Bedekking kruidlaag (%)  Bedekking moslaag (%)  Hoogte (hoge) boomlaag (m)  \
# 0                     70.0                    NaN                         NaN
#
#    Hoogte lage boomlaag (m)  Hoogte (hoge) struiklaag (m)  \
# 0                       NaN                           NaN
#
#    Hoogte lage struiklaag (m)  Gem. hoogte (hoge) kruidl (cm)  \
# 0                         NaN                             NaN
#
#    Gem. hoogte lage kruidl. (cm)  Maximale hoogte kruidlaag (cm)  \
# ...

# %%
pd.set_option('display.max_columns', None)
species.head(n=20)
# Out:
#     PlotObservationID                 Species name  Layer  Cover % Cover code  \
# 0                 192  Bolboschoenus maritimus s.s      0      2.0          +
# 1                 192         Phragmites australis      0     68.0          4
# 2                 192            Solanum dulcamara      0      2.0          +
# 3                 196         Agrostis stolonifera      0      2.0          +
# 4                 196      Calamagrostis canescens      0      2.0          +
# 5                 196           Epilobium hirsutum      0     18.0         2b
# 6                 196            Lycopus europaeus      0      2.0          +
# 7                 196         Phragmites australis      0     68.0          4
# 8                 196          Potentilla anserina      0      1.0          r
# 9                 196                Rubus species      0      1.0          r
# 10                196                 Salix repens      0      1.0          r
# ...
